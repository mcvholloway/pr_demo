# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, np.pi*2, 500)
y = np.sin(x)**2

# %%
plt.plot(x,y);

# %%
x = np.linspace(0, np.pi*2, 500)
y = np.tan(x)**2

# %%
plt.plot(x,y);
